# %% [markdown]
# # Stage 3.5M — WiSig ManyTx Zero-Day/Open-Set Detection
# Run preflight only after checking out the reviewed `codex/stage3-5m` commit. Do not start the full run until the GitHub leakage/locking review is complete.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content
# !test -d Surrogate-XAI/.git || git clone --branch codex/stage3-5m --single-branch https://github.com/VSudha369/Surrogate-XAI.git
# %cd /content/Surrogate-XAI
# !git pull --ff-only origin codex/stage3-5m
# !python -u Stage3_5M_Colab_Launcher_v1_0_0.py --preflight

# %%
# Run only after GitHub code/diff review approves the strict protocol.
# !python -u Stage3_5M_Colab_Launcher_v1_0_0.py --resume
