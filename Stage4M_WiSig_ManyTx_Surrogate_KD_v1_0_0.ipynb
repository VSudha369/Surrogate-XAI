# %% [markdown]
# # Stage 4M v1.0.0 — preflight only
# This notebook intentionally stops at the review gate; it does not launch canonical KD training.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# %%
import pathlib, shutil, subprocess
repo = pathlib.Path('/content/Surrogate-XAI')
if repo.exists(): shutil.rmtree(repo)
subprocess.check_call(['git', 'clone', '--branch', 'codex/stage4m', '--single-branch', 'https://github.com/VSudha369/Surrogate-XAI.git', str(repo)])

# %%
import subprocess, sys
subprocess.check_call([sys.executable, '-u', '/content/Surrogate-XAI/Stage4M_Colab_Launcher_v1_0_0.py', '--repository-root', '/content/Surrogate-XAI', '--preflight'])

# %% [markdown]
# Stop here and submit `STAGE4M_PREFLIGHT_PASS` plus the Drive preflight manifest for review.
